# %%
import pandas as pd
import numpy as np

# %%
# Reading data (Both Local and Online)

# %%
# Local data
df = pd.read_csv("sampleData/Internship_Data.csv")
# Online data
# df = pd.read_csv("http://bit.ly/CitiesDataset1")
# preview the first five records
df.head()
# Out:
#       Name  Squad Number Do you have any preferred language of communication?  \
# 0  Grayson           NaN  i prefer english but i am also able to communi...
# 1    Jonas           NaN                                            English
# 2    Ronan           NaN               English and Spanish are good for me.
# 3    Dulce           NaN                                            spanish
# 4   Evelyn           NaN                                            Spanish
#
#   What Group Virtual Internship Program are you interested in registering for  \
# 0                  Product Marketing,Product Growth
# 1   Product Marketing,Product Growth ,Product Design
# 2                                     Product Design
# 3                                     Product Design
# 4                                  Product Marketing
#
#     Age                     City Country 1    Country    Region  \
# 0  23.0       bordj bou arreridj       NaN    Algeria      MENA
# ...

# %%
# Data Exploration

# %%
# Determine number of records in the dataset
# shape - returns no of records/instances - (left) and columns/variables (right)
df.shape
# Out:
# (1188, 30)

# %%
# to preview our dataset
df.sample()
# Out:
#       Name  Squad Number Do you have any preferred language of communication?  \
# 276  Alani           NaN                        1)English 2)French 3)Arabic
#
#     What Group Virtual Internship Program are you interested in registering for  \
# 276                                Product Development
#
#       Age     City Country 1  Country Region Time Zone  ...  \
# 276  20.0  Tripoli     Other  Lebanon   MENA      Asia  ...
#
#     In case we are not able to accommodate your primary role request, please select other roles you would be willing to take on.  \
# 276  Web Developer,UI Developer ,Cloud Developer,AI...
#
#     For the Product Growth Internship, what is your desired role?  \
# 276                                                NaN
#
#     In case we are not able to accommodate your primary role request due to cohort limitations, what other roles would you be willing to take on?  \
# 276                                                NaN
#
# ...

# %%
# preview the last 5 records
df.tail()
# Out:
#            Name  Squad Number  \
# 1183  Johnathan           NaN
# 1184     Adriel           NaN
# 1185      Reyna           NaN
# 1186      Uriel           NaN
# 1187    Esteban           NaN
#
#      Do you have any preferred language of communication?  \
# 1183                                            English
# 1184  English is the language I am most comfortable ...
# 1185                                            English
# 1186                                            English
# 1187                                         Vietnamese
#
#      What Group Virtual Internship Program are you interested in registering for  \
# 1183                Product Development,Product Growth
# 1184                                Product Development
# 1185                                     Product Design
# 1186   Product Marketing,Product Design,Product Growth
# 1187                                Product Development
#
#        Age                    City Country 1    Country    Region  \
# ...

# %%
# check data types of variables using dtypes - property
df.dtypes
# Out:
# Name                                                                                                                                              object
# Squad Number                                                                                                                                     float64
# Do you have any preferred language of communication?                                                                                              object
# What Group Virtual Internship Program are you interested in registering for                                                                       object
# Age                                                                                                                                              float64
# City                                                                                                                                              object
# ...

# %%
df.head()
# Out:
#       Name  Squad Number Do you have any preferred language of communication?  \
# 0  Grayson           NaN  i prefer english but i am also able to communi...
# 1    Jonas           NaN                                            English
# 2    Ronan           NaN               English and Spanish are good for me.
# 3    Dulce           NaN                                            spanish
# 4   Evelyn           NaN                                            Spanish
#
#   What Group Virtual Internship Program are you interested in registering for  \
# 0                  Product Marketing,Product Growth
# 1   Product Marketing,Product Growth ,Product Design
# 2                                     Product Design
# 3                                     Product Design
# 4                                  Product Marketing
#
#     Age                     City Country 1    Country    Region  \
# 0  23.0       bordj bou arreridj       NaN    Algeria      MENA
# ...

# %%
# handling erelevant data

# Deleting an Irrelevant Column i.e. if we didn't require the column <of choice>
# to answer our research question.
# ---
# While dropping/deleting those two columns:
# a) We set axis = 1
#    A dataframe has two axes: “axis 0” and “axis 1”.
#    “axis 0” represents rows and “axis 1” represents columns.
# b) We can also set Inplace = True.
#    This means the changes would be made to the original dataframe.
# Dropping the irrelevant columns i.e. Team and Weight
# Those values were dropped since axis was set equal to 1 and
# the changes were made in the original data frame since inplace was True.

# %%
df.drop(['For the Product Growth Internship, what is your desired role?'], axis=1, inplace=True)
df.head()
# Out:
#   Do you have any preferred language of communication?  \
# 0  i prefer english but i am also able to communi...
# 1                                            English
# 2               English and Spanish are good for me.
# 3                                            spanish
# 4                                            Spanish
#
#   What Group Virtual Internship Program are you interested in registering for  \
# 0                  Product Marketing,Product Growth
# 1   Product Marketing,Product Growth ,Product Design
# 2                                     Product Design
# 3                                     Product Design
# 4                                  Product Marketing
#
#     Age                     City Country 1    Country    Region  \
# 0  23.0       bordj bou arreridj       NaN    Algeria      MENA
# 1  23.0                  Algiers       NaN    Algeria      MENA
# 2  34.0  Buenos Aires, Argentina       NaN  Argentina  Americas
# ...
